# %%
A = [10, 20, 30] 
B = [10 20 30]   
C = [10; 20; 30] 
A == B, A == C
# Out:
# (false, true)

# %%
A
# Out:
# 3-element Array{Int64,1}:
#  10
#  20
#  30

# %%
B
# Out:
# 1×3 Array{Int64,2}:
#  10  20  30

# %%
C
# Out:
# 3-element Array{Int64,1}:
#  10
#  20
#  30

# %%
A[1] = 111
A
# Out:
# 3-element Array{Int64,1}:
#  111
#   20
#   30

# %% [markdown]
# # Matrix Ops

# %%
M = [1 2 3; 4 5 6; 7 8 9]
# Out:
# 3×3 Array{Int64,2}:
#  1  2  3
#  4  5  6
#  7  8  9

# %%
M[1, 2] = 12
M
# Out:
# 3×3 Array{Int64,2}:
#  1  12  3
#  4   5  6
#  7   8  9

# %%
M'
# Out:
# 3×3 LinearAlgebra.Adjoint{Int64,Array{Int64,2}}:
#   1  4  7
#  12  5  8
#   3  6  9

# %%
inv(M)
# Out:
# 3×3 Array{Float64,2}:
#  -0.05  -1.4       0.95
#   0.1   -0.2       0.1
#  -0.05   1.26667  -0.716667

# %% [markdown]
# # Dictionary

# %%
D = Dict("name" => "dict", "Year" => 2020)
# Out:
# Dict{String,Any} with 2 entries:
#   "name" => "dict"
#   "Year" => 2020

# %%
D["Year"]
# Out:
# 2020

# %%
D.count
# Out:
# 2

# %% [markdown]
# # Strings

# %%
text = "just a string"
println(text[1])
println(length(text))
# Out:
# j
# 13

# %% [markdown]
# # Control

# %%
fact = 1
for i in 1:5
    fact *= i
end
print(fact)
# Out:
# 120
