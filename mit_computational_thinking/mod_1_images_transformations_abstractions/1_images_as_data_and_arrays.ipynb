# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
using Colors
using ColorVectorSpace
using FileIO
using HypertextLiteral
using ImageIO
using ImageShow
using PlutoTeachingTools

# %%
url = (
    "https://user-images.githubusercontent.com/6933510/"
    * "107239146-dcc3fd00-6a28-11eb-8c7b-41aaf6618935.png")
philip_filename = download(url) 
philip = load(philip_filename)
philip
# Out:
# 864×700 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.157, 0.141, 0.106)  …  RGB(0.702, 0.722, 0.737)
#  RGB(0.157, 0.141, 0.106)     RGB(0.702, 0.722, 0.737)
#  RGB(0.157, 0.141, 0.106)     RGB(0.702, 0.722, 0.737)
#  RGB(0.157, 0.141, 0.106)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)  …  RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)  …  RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  RGB(0.145, 0.129, 0.094)     RGB(0.702, 0.722, 0.737)
#  ⋮                         ⋱
#  RGB(0.898, 0.792, 0.616)     RGB(0.749, 0.592, 0.361)
#  RGB(0.867, 0.761, 0.588)     RGB(0.753, 0.596, 0.365)
#  RGB(0.847, 0.741, 0.565)     RGB(0.741, 0.584, 0.353)
# ...

# %%
@bind myface1 PlutoUI.WebcamInput(help=false, max_size=150)
# Out:
# LoadError: UndefVarError: `@bind` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
# in expression starting at In[11]:1
#
# Stacktrace:
#  [1] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
[philip              philip[   :    , end:-1:1]
 philip[end:-1:1, :] philip[end:-1:1, end:-1:1]]
# Out:
# 1728×1400 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.157, 0.141, 0.106)  …  RGB(0.157, 0.141, 0.106)
#  RGB(0.157, 0.141, 0.106)     RGB(0.157, 0.141, 0.106)
#  RGB(0.157, 0.141, 0.106)     RGB(0.157, 0.141, 0.106)
#  RGB(0.157, 0.141, 0.106)     RGB(0.157, 0.141, 0.106)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)  …  RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)  …  RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  ⋮                         ⋱
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
#  RGB(0.145, 0.129, 0.094)     RGB(0.145, 0.129, 0.094)
# ...

# %%
philip_size = size(philip)
philip_h, philip_w = philip_size
philip_h, philip_w
# Out:
# (864, 700)

# %%
a_pxl = philip[432, 350]
a_pxl
# Out:
# RGB{N0f8}(0.776, 0.733, 0.725)

# %%
row, col = (216, 175)
philip[row, col]
# Out:
# RGB{N0f8}(0.839, 0.875, 0.925)

# %%
philip[550:650, :]
# Out:
# 101×700 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.906, 0.796, 0.639)  …  RGB(0.498, 0.478, 0.463)
#  RGB(0.882, 0.796, 0.627)     RGB(0.486, 0.467, 0.451)
#  RGB(0.902, 0.82, 0.651)      RGB(0.482, 0.463, 0.447)
#  RGB(0.867, 0.784, 0.616)     RGB(0.482, 0.463, 0.447)
#  RGB(0.835, 0.753, 0.584)     RGB(0.482, 0.463, 0.447)
#  RGB(0.922, 0.824, 0.659)  …  RGB(0.482, 0.463, 0.447)
#  RGB(0.925, 0.816, 0.659)     RGB(0.478, 0.459, 0.443)
#  RGB(0.851, 0.741, 0.584)     RGB(0.478, 0.459, 0.443)
#  RGB(0.89, 0.784, 0.627)      RGB(0.478, 0.459, 0.443)
#  RGB(0.933, 0.824, 0.663)     RGB(0.482, 0.463, 0.447)
#  RGB(0.871, 0.765, 0.588)  …  RGB(0.486, 0.467, 0.451)
#  RGB(0.871, 0.765, 0.588)     RGB(0.486, 0.467, 0.451)
#  RGB(0.894, 0.788, 0.612)     RGB(0.486, 0.467, 0.451)
#  ⋮                         ⋱
#  RGB(0.894, 0.788, 0.612)     RGB(0.012, 0.012, 0.012)
#  RGB(0.878, 0.773, 0.596)  …  RGB(0.012, 0.012, 0.012)
#  RGB(0.878, 0.773, 0.596)     RGB(0.012, 0.012, 0.012)
# ...

# %%
philip[600, :]
# Out:
# 700-element Vector{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.898, 0.78, 0.576)
#  RGB(0.898, 0.78, 0.576)
#  RGB(0.89, 0.773, 0.569)
#  RGB(0.835, 0.718, 0.514)
#  RGB(0.831, 0.714, 0.514)
#  RGB(0.859, 0.741, 0.541)
#  RGB(0.894, 0.776, 0.573)
#  RGB(0.906, 0.788, 0.584)
#  RGB(0.878, 0.769, 0.604)
#  RGB(0.878, 0.769, 0.612)
#  RGB(0.886, 0.776, 0.62)
#  RGB(0.898, 0.788, 0.631)
#  RGB(0.918, 0.808, 0.651)
#  ⋮
#  RGB(0.224, 0.149, 0.09)
#  RGB(0.239, 0.165, 0.106)
#  RGB(0.251, 0.176, 0.118)
#  RGB(0.259, 0.188, 0.141)
#  RGB(0.267, 0.208, 0.188)
#  RGB(0.278, 0.22, 0.2)
#  RGB(0.294, 0.235, 0.216)
#  RGB(0.302, 0.243, 0.224)
#  RGB(0.329, 0.271, 0.251)
#  RGB(0.341, 0.282, 0.263)
#  RGB(0.373, 0.314, 0.294)
#  RGB(0.404, 0.345, 0.325)

# %%
p_head = philip[470:800, 140:380]
# Out:
# 331×241 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.647, 0.451, 0.318)  …  RGB(0.906, 0.925, 0.941)
#  RGB(0.686, 0.455, 0.302)     RGB(0.867, 0.886, 0.902)
#  RGB(0.894, 0.714, 0.478)     RGB(0.875, 0.89, 0.933)
#  RGB(0.824, 0.643, 0.408)     RGB(0.859, 0.875, 0.918)
#  RGB(0.867, 0.686, 0.451)     RGB(0.82, 0.835, 0.878)
#  RGB(0.82, 0.639, 0.404)   …  RGB(0.867, 0.882, 0.925)
#  RGB(0.824, 0.643, 0.408)     RGB(0.859, 0.875, 0.918)
#  RGB(0.827, 0.647, 0.412)     RGB(0.843, 0.859, 0.902)
#  RGB(0.831, 0.651, 0.416)     RGB(0.839, 0.855, 0.898)
#  RGB(0.839, 0.659, 0.424)     RGB(0.851, 0.867, 0.91)
#  RGB(0.827, 0.647, 0.412)  …  RGB(0.831, 0.847, 0.89)
#  RGB(0.867, 0.686, 0.455)     RGB(0.824, 0.839, 0.882)
#  RGB(0.871, 0.69, 0.455)      RGB(0.835, 0.851, 0.894)
#  ⋮                         ⋱  ⋮
#  RGB(0.839, 0.757, 0.588)     RGB(0.314, 0.192, 0.122)
#  RGB(0.867, 0.784, 0.616)  …  RGB(0.314, 0.192, 0.122)
#  RGB(0.882, 0.8, 0.631)       RGB(0.314, 0.192, 0.122)
# ...

# %%
RGB(1., 0., 0.)
# Out:
# RGB{Float64}(1.0, 0.0, 0.0)

# %%
RGB(0.1, 0.5, 1.)
# Out:
# RGB{Float64}(0.1, 0.5, 1.0)

# %%
function invert(color::AbstractRGB)
    return RGB(1 - color.r, 1 - color.g, 1 - color.b)
end
# Out:
# invert (generic function with 1 method)

# %%
green = RGB(0, 1, 0)
green
# Out:
# RGB{N0f8}(0.0, 1.0, 0.0)

# %%
invert(green)
# Out:
# RGB{Float32}(1.0, 0.0, 1.0)

# %%
invert.(philip)
# Out:
# 864×700 Matrix{RGB{Float32}}:
#  RGB(0.843137, 0.858824, 0.894118)  …  RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.843137, 0.858824, 0.894118)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.843137, 0.858824, 0.894118)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.843137, 0.858824, 0.894118)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)  …  RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)  …  RGB(0.298039, 0.278431, 0.262745)
#  RGB(0.854902, 0.870588, 0.905882)     RGB(0.298039, 0.278431, 0.262745)
# ...

# %%
temp = copy(p_head)
temp[50:100, 50:100] = invert.(temp[50:100, 50:100])
temp
# Out:
# 331×241 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.647, 0.451, 0.318)  …  RGB(0.906, 0.925, 0.941)
#  RGB(0.686, 0.455, 0.302)     RGB(0.867, 0.886, 0.902)
#  RGB(0.894, 0.714, 0.478)     RGB(0.875, 0.89, 0.933)
#  RGB(0.824, 0.643, 0.408)     RGB(0.859, 0.875, 0.918)
#  RGB(0.867, 0.686, 0.451)     RGB(0.82, 0.835, 0.878)
#  RGB(0.82, 0.639, 0.404)   …  RGB(0.867, 0.882, 0.925)
#  RGB(0.824, 0.643, 0.408)     RGB(0.859, 0.875, 0.918)
#  RGB(0.827, 0.647, 0.412)     RGB(0.843, 0.859, 0.902)
#  RGB(0.831, 0.651, 0.416)     RGB(0.839, 0.855, 0.898)
#  RGB(0.839, 0.659, 0.424)     RGB(0.851, 0.867, 0.91)
#  RGB(0.827, 0.647, 0.412)  …  RGB(0.831, 0.847, 0.89)
#  RGB(0.867, 0.686, 0.455)     RGB(0.824, 0.839, 0.882)
#  RGB(0.871, 0.69, 0.455)      RGB(0.835, 0.851, 0.894)
#  ⋮                         ⋱  ⋮
#  RGB(0.839, 0.757, 0.588)     RGB(0.314, 0.192, 0.122)
#  RGB(0.867, 0.784, 0.616)  …  RGB(0.314, 0.192, 0.122)
#  RGB(0.882, 0.8, 0.631)       RGB(0.314, 0.192, 0.122)
# ...
