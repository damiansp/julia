# %%
nt = (a=1, b=2.2)
# Out:
# (a = 1, b = 2.2)

# %%
nt.b
# Out:
# 2.2

# %%
keys(nt)
# Out:
# (:a, :b)

# %%
values(nt)
# Out:
# (1, 2.2)

# %%
collect(nt)
# Out:
# 2-element Array{Real,1}:
#  1
#  2.2

# %%
for (name, val) in pairs(nt)
    println("$name => $val")
end
# Out:
# a => 1
# b => 2.2
