# %% [markdown]
# ### 2 Strings

# %%
a = "a string"
b = "another\nstring\n"
c = """
a
multiline
string
"""
a[3]
# Out:
# 's': ASCII/Unicode U+0073 (category Ll: Letter, lowercase)

# %%
split(b)
# Out:
# 2-element Array{SubString{String},1}:
#  "another"
#  "string"

# %%
join([a, b], " and ")
# Out:
# "a string and another\nstring\n"

# %%
replace(b, "th" => "dd")
# Out:
# "anodder\nstring\n"

# %%
strip("   too much whitespace     ")
# Out:
# "too much whitespace"

# %%
parse(Int, "2017")
# Out:
# 2017

# %%
string(123)
# Out:
# "123"

# %%
string(a, b)
# Out:
# "a stringanother\nstring\n"

# %%
string(a * " " * b)
# Out:
# "a string another\nstring\n"

# %%
print("$a is the thing")
# Out:
# a string is the thing
