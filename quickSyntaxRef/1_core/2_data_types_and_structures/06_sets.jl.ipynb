# %%
s = Set()
# Out:
# Set{Any} with 0 elements

# %%
s = Set{Int32}()
# Out:
# Set{Int32} with 0 elements

# %%
s = Set([1, 2, 3, 3, 4])
# Out:
# Set{Int64} with 4 elements:
#   4
#   2
#   3
#   1

# %%
push!(s, 3)
# Out:
# Set{Int64} with 4 elements:
#   4
#   2
#   3
#   1

# %%
push!(s, 5)
# Out:
# Set{Int64} with 5 elements:
#   4
#   2
#   3
#   5
#   1

# %%
delete!(s, 2)
# Out:
# Set{Int64} with 4 elements:
#   4
#   3
#   5
#   1

# %%
t = Set([3, 5, 7])
# Out:
# Set{Int64} with 3 elements:
#   7
#   3
#   5

# %%
intersect(s, t)
# Out:
# Set{Int64} with 2 elements:
#   3
#   5

# %%
union(s, t)
# Out:
# Set{Int64} with 5 elements:
#   7
#   4
#   3
#   5
#   1

# %%
setdiff(s, t)
# Out:
# Set{Int64} with 2 elements:
#   4
#   1

# %%
setdiff(t, s)
# Out:
# Set{Int64} with 1 element:
#   7
