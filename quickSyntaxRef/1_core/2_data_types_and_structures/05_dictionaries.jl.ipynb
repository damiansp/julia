# %%
d = Dict('a' => 1, 'b' => 2, 'c' => 3)
# Out:
# Dict{Char,Int64} with 3 entries:
#   'a' => 1
#   'c' => 3
#   'b' => 2

# %%
d['c']
# Out:
# 3

# %%
delete!(d, 'b')
# Out:
# Dict{Char,Int64} with 2 entries:
#   'a' => 1
#   'c' => 3

# %%
map((k, v) -> d[k] = v, ['A', 'B', 'C'], [10, 20, 30])
d
# Out:
# Dict{Char,Int64} with 5 entries:
#   'C' => 30
#   'A' => 10
#   'a' => 1
#   'c' => 3
#   'B' => 20

# %%
get(d, 'A', 0), get(d, 'd', 4)
# Out:
# (10, 4)

# %%
keys(d)
# Out:
# Base.KeySet for a Dict{Char,Int64} with 5 entries. Keys:
#   'C'
#   'A'
#   'a'
#   'c'
#   'B'

# %%
values(d)
# Out:
# Base.ValueIterator for a Dict{Char,Int64} with 5 entries. Values:
#   30
#   10
#   1
#   3
#   20

# %%
haskey(d, 'a'), haskey(d, 'F')
# Out:
# (true, false)

# %%
in('a' => 1, d)
# Out:
# true

# %%
for (k, v) in d
    println("$k => $v")
end
# Out:
# C => 30
# A => 10
# a => 1
# c => 3
# B => 20

# %%
d = Dict(:k1 => "v1", :k2 => 2)
typeof(d)
# Out:
# Dict{Symbol,Any}

# %%
nt = (k1="v1", k2=2)
typeof(nt)
# Out:
# NamedTuple{(:k1, :k2),Tuple{String,Int64}}
