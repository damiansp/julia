# %%
a = [[[1, 2], 3], 4]
b = a
c = copy(a)
d = deepcopy(a)
# Out:
# 2-element Array{Any,1}:
#   Any[[1, 2], 3]
#  4

# %%
a[2] = 40
print(b)
# Out:
# Any[Any[[1, 2], 3], 40]

# %%
print(c)
# Out:
# Any[Any[[1, 2], 3], 4]

# %%
print(d)
# Out:
# Any[Any[[1, 2], 3], 4]

# %%
a[1][2] = 30
print(b)
# Out:
# Any[Any[[1, 2], 30], 40]

# %%
print(c)
# Out:
# Any[Any[[1, 2], 30], 4]

# %%
print(d)
# Out:
# Any[Any[[1, 2], 3], 4]

# %%
a[1][1][2] = 20
print(b)
# Out:
# Any[Any[[1, 20], 30], 40]

# %%
print(c)
# Out:
# Any[Any[[1, 20], 30], 4]

# %%
print(d)
# Out:
# Any[Any[[1, 2], 3], 4]

# %%
a = 5
print(b)
# Out:
# Any[Any[[1, 20], 30], 40]

# %%
print(c)
# Out:
# Any[Any[[1, 20], 30], 4]

# %%
print(d)
# Out:
# Any[Any[[1, 2], 3], 4]

# %%
a = [1, 2]
b = [1, 2]
a == b, a === a, a === b
# Out:
# (true, true, false)

# %%
a = (1, 2)
b = (1, 2)
a == b, a === a, a === b
# Out:
# (true, true, true)
