# %%
t = 1, 2.5, 'a'
u = (2, 5., "b")
# Out:
# (2, 5.0, "b")

# %%
x, y = (1, 22)
y
# Out:
# 22

# %%
t = (1, 2, 3)
a = [t...]
a
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
a = [i for i in t]
a
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
a = collect(t)
a
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3
