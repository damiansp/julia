# %%
using Distributions
import Random:seed!

# %%
parse.(Float64, ["1.1", "2.3"])
# Out:
# 2-element Array{Float64,1}:
#  1.1
#  2.3

# %%
rand()
# Out:
# 0.6705874932178959

# %%
rand(2:7)
# Out:
# 3

# %%
rand(2:0.001:7)
# Out:
# 2.739

# %%
rand(Uniform(2, 7))
# Out:
# 4.107738634526984

# %%
rand(Normal(0, 1))
# Out:
# -0.9634143459194868

# %%
rand(Poisson(3))
# Out:
# 3

# %%
seed!(123)
rand(2:22), rand(2:22)
# Out:
# (6, 16)

# %%
seed!(123)
rand(2:22), rand(2:22)
# Out:
# (6, 16)

# %%
seed!()
rand(2:22), rand(2:22)
# Out:
# (6, 13)

# %%
nothing  # R: NULL

# %%
typeof(nothing)
# Out:
# Nothing

# %%
missing # R: NA
# Out:
# missing

# %%
typeof(missing)
# Out:
# Missing

# %%
NaN # R: NaN
# Out:
# NaN

# %%
typeof(NaN)
# Out:
# Float64

# %%
1 / 0
# Out:
# Inf

# %%
0 / 0
# Out:
# NaN
