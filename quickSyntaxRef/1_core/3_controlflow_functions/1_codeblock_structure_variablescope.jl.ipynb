# %%
for i in 1:5
    println(i)
end
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = 4
while a > 2
    a -= 1
    println(a)
end
# Out:
# 3
# 2

# %%
a
# Out:
# 2

# %%
a = 5
while a > 2
    global a
    println("a: $a")
    b = a
    while b > 2
        println("  b: $b")
        b -= 1
    end
    a -=1
end
# Out:
# a: 5
#   b: 5
#   b: 4
#   b: 3
# a: 4
#   b: 4
#   b: 3
# a: 3
#   b: 3

# %%
a, b
# Out:
# UndefVarError: b not defined
#
# Stacktrace:
#  [1] top-level scope at In[7]:1

# %%
a
# Out:
# 2
