# %%
for i = 1:2, j = 2:5
    println("i: $i / j: $j")
end
# Out:
# i: 1 / j: 2
# i: 1 / j: 3
# i: 1 / j: 4
# i: 1 / j: 5
# i: 2 / j: 2
# i: 2 / j: 3
# i: 2 / j: 4
# i: 2 / j: 5

# %%
[x^2 for x in [1, 2, 3, 4]]
# Out:
# 4-element Array{Int64,1}:
#   1
#   4
#   9
#  16

# %%
[2x - 3y for x in [10, 20, 30], y in [1, 2, 3]]
# Out:
# 3×3 Array{Int64,2}:
#  17  14  11
#  37  34  31
#  57  54  51

# %%
mydict = Dict()
[mydict[i] = value 
 for (i, value) in enumerate(["apples", "bananas", "cherries"])]
mydict
# Out:
# Dict{Any,Any} with 3 entries:
#   2 => "bananas"
#   3 => "cherries"
#   1 => "apples"

# %%
names = ["Alice", "Bob", "Carol", "Dave"]
sexes = ['F', 'M', 'F', 'M']
students = Dict()
[students[name] = sex for (name, sex) in zip(names, sexes)]
students
# Out:
# Dict{Any,Any} with 4 entries:
#   "Carol" => 'F'
#   "Alice" => 'F'
#   "Dave"  => 'M'
#   "Bob"   => 'M'
