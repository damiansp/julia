# %% [markdown]
# # Defining Methods

# %%
f(x::Float64, y::Float64) = 2x + y
# Out:
# f (generic function with 1 method)

# %%
f(2., 3.)
# Out:
# 7.0

# %%
f(2., 3)
# Out:
# MethodError: no method matching f(::Float64, ::Int64)
# Closest candidates are:
#   f(::Float64, !Matched::Float64) at In[1]:1
#
# Stacktrace:
#  [1] top-level scope at In[3]:1

# %%
f(x::Number, y::Number) = 3x - y
# Out:
# f (generic function with 2 methods)

# %%
f(2., 4)
# Out:
# 2.0

# %%
f(3, 4.)
# Out:
# 5.0

# %%
f(x, y) = println("Whoa there, Nelly") # args default to Any
# Out:
# f (generic function with 3 methods)

# %%
f("foo", 1)
# Out:
# Whoa there, Nelly

# %% [markdown]
# # Method Ambiguities

# %%
g(x::Float64, y) = 2x + y
# Out:
# g (generic function with 1 method)

# %%
g(x, y::Float64) = x + 2y
# Out:
# g (generic function with 2 methods)

# %%
g(2., 3), g(2, 3.)
# Out:
# (7.0, 8.0)

# %%
g(2., 3.)
# Out:
# MethodError: g(::Float64, ::Float64) is ambiguous. Candidates:
#   g(x, y::Float64) in Main at In[3]:1
#   g(x::Float64, y) in Main at In[1]:1
# Possible fix, define
#   g(::Float64, ::Float64)
#
# Stacktrace:
#  [1] top-level scope at In[5]:1

# %%
g(x::Float64, y::Float64) = 2x + 2y
# Out:
# g (generic function with 3 methods)

# %%
g(2., 3.)
# Out:
# 10.0

# %% [markdown]
# # Parametric Methods

# %%
same_type(x::T, y::T) where {T} = true
# Out:
# same_type (generic function with 1 method)

# %%
same_type(x, y) = false
# Out:
# same_type (generic function with 2 methods)

# %%
same_type(1, 2), same_type(1., 2)
# Out:
# (true, false)

# %%
same_type("foo", "bar"), same_type(Int32(1), Int64(2))
# Out:
# (true, false)

# %%
myappend(v::Vector{T}, x::T) where {T} = [v..., x]
# Out:
# myappend (generic function with 1 method)

# %%
myappend([1, 2, 3], 4)
# Out:
# 4-element Array{Int64,1}:
#  1
#  2
#  3
#  4

# %%
myappend([1, 2, 3], 4.)
# Out:
# MethodError: no method matching myappend(::Array{Int64,1}, ::Float64)
# Closest candidates are:
#   myappend(::Array{T,1}, !Matched::T) where T at In[13]:1
#
# Stacktrace:
#  [1] top-level scope at In[15]:1

# %%
mytypeof(x::T) where {T} = T
# Out:
# mytypeof (generic function with 1 method)

# %%
mytypeof(1), mytypeof(1.)
# Out:
# (Int64, Float64)

# %%
same_type_numeric(x::T, y::T) where {T <: Number} = true
# Out:
# same_type_numeric (generic function with 1 method)

# %%
same_type_numeric(x::Number, y::Number) = false
# Out:
# same_type_numeric (generic function with 2 methods)

# %%
same_type_numeric(1, 2), same_type_numeric(1., 2.)
# Out:
# (true, true)

# %%
same_type_numeric(1, 2.)
# Out:
# false

# %% [markdown]
# # Redefining Methods

# %%
function tryeval()
    @eval newfun() = 1
    newfun()
end
# Out:
# tryeval (generic function with 1 method)

# %%
tryeval()
# Out:
# MethodError: no method matching newfun()
# The applicable method may be too new: running in world age 25573, while current world is 25574.
# Closest candidates are:
#   newfun() at In[1]:2 (method too new to be called from this world context.)
#
# Stacktrace:
#  [1] tryeval() at ./In[1]:3
#  [2] top-level scope at In[2]:1

# %%
newfun()
# Out:
# 1

# %%
function tryeval2()
    @eval newfun2() = 2
    Base.invokelatest(newfun2)
end
# Out:
# tryeval2 (generic function with 1 method)

# %%
tryeval2()
# Out:
# 2

# %%
f(x) = "original definition"
# Out:
# f (generic function with 1 method)

# %%
g(x) = f(x)
# Out:
# g (generic function with 1 method)

# %%
t = @async f(wait())
yield()

# %%
f(1)
# Out:
# "original definition"

# %%
f(x::Int) = "definition for Int"
# Out:
# f (generic function with 2 methods)

# %%
f(x::Type{Int}) = "definition for Type{Int}"
# Out:
# f (generic function with 3 methods)

# %%
f(1)
# Out:
# "definition for Int"

# %%
g(1)
# Out:
# "definition for Int"

# %%
fetch(schedule(t, 1))
# Out:
# "original definition"

# %%
t = @async f(wait())
yield()

# %%
fetch(schedule(t, 1))
# Out:
# "definition for Int"

# %% [markdown]
# # Design Patterns with Parametric Methods
# ## Extracting the type parameter from a super-type

# %%
abstract type AbstractArray{T, N} end
eltype(::Type{<: AbstractArray{T}}) where {T} = T
# Out:
# eltype (generic function with 1 method)

# %%
abstract type AbstractArray{T, N} end
eltype(::Type{AbstractArray}) = Any
eltype(::Type{AbstractArray{T}}) where {T} = T
eltype(::Type{AbstractArray{T, N}}) where {T, N} = T
eltype(::Type{A}) where {A <: AbstractArray} = eltype(supertype(A))
# Out:
# eltype (generic function with 5 methods)

# %%
eltype_wrong(::Type{A}) where {A <: AbstractArray} = A.parameters[1]
# Out:
# eltype_wrong (generic function with 1 method)

# %%
struct BitVector <: AbstractArray{Bool, 1}
end
