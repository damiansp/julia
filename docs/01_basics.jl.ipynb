# %%
x = 10
x + 1
# Out:
# 11

# %%
x = 1 + 1
x
# Out:
# 2

# %%
x = "Hello"
# Out:
# "Hello"

# %%
[1, 2, 3] .^ 2
# Out:
# 3-element Array{Int64,1}:
#  1
#  4
#  9

# %%
'x'
# Out:
# 'x': ASCII/Unicode U+0078 (category Ll: Letter, lowercase)

# %%
Int('x')
# Out:
# 120

# %%
Char(120)
# Out:
# 'x': ASCII/Unicode U+0078 (category Ll: Letter, lowercase)

# %%
'\u2200'
# Out:
# '∀': Unicode U+2200 (category Sm: Symbol, math)

# %%
'A' + 4
# Out:
# 'E': ASCII/Unicode U+0045 (category Lu: Letter, uppercase)

# %%
str = "long string"
SubString(str, 2, 6)
# Out:
# "ong s"

# %%
s = "\u2200 x \u2203 y"
# Out:
# "∀ x ∃ y"

# %%
s[1:4]
# Out:
# "∀ "

# %%
for i = firstindex(s):lastindex(s)
    try
        println(s[i])
    catch
        # ignroe
    end
end
# Out:
# ∀
#
# x
#
# ∃
#
# y

# %%
for c in s
    println(c)
end
# Out:
# ∀
#
# x
#
# ∃
#
# y

# %%
greet = "Hey"
entity = "Bob"
println(string(greet, ", ", entity, "!\n"))
# Out:
# Hey, Bob!

# %%
greet * ", " * entity * "!"
# Out:
# "Hey, Bob!"

# %%
"$greet, $entity"
# Out:
# "Hey, Bob"

# %%
occursin('o', entity)
# Out:
# true

# %%
occursin("ob", entity)
# Out:
# true

# %%
repeat("_.:Z:.", 5)
# Out:
# "_.:Z:._.:Z:._.:Z:._.:Z:._.:Z:."

# %%
join(['a', 'b', 'c'], ", ")
# Out:
# "a, b, c"

# %%
join(['a', 'b', 'c', 'd'], ", ", ", and ")
# Out:
# "a, b, c, and d"

# %%
length("this string")
# Out:
# 11

# %%
re = r"^\s*(?:#|$)"
# Out:
# r"^\s*(?:#|$)"

# %%
typeof(re)
# Out:
# Regex

# %%
occursin(re, "not a comment")
# Out:
# false

# %%
occursin(re, "# a comment")
# Out:
# true

# %%
m = match(re, "this line")
if m == nothing 
    println("not a comment")
else
    println("blank or comment")
end
# Out:
# not a comment

# %%
m = match(r"(a.|i.)", "damian")
# Out:
# RegexMatch("am", 1="am")

# %%
m = match(r"(a.|i.)", "damian", 3)
# Out:
# RegexMatch("ia", 1="ia")

# %%
m.match
# Out:
# "ia"

# %%
m.captures
# Out:
# 1-element Array{Union{Nothing, SubString{String}},1}:
#  "ia"

# %%
m.offset
# Out:
# 4

# %%
using Dates

# %%
d = Date(1976, 11, 3)
# Out:
# 1976-11-03

# %%
day(d)
# Out:
# 3

# %%
month(d)
# Out:
# 11

# %%
year(d)
# Out:
# 1976

# %%
println(raw"\\ \\\"")
# Out:
# \\ \"

# %%
println(raw"\ \\ \\\ \\\\ \\\\\ ")
# Out:
# \ \\ \\\ \\\\ \\\\\
