# %%
length("julia")
# Out:
# 5

# %%
sizeof(""), sizeof("a"), sizeof("π"), sizeof("龙")
# Out:
# (0, 1, 2, 3)

# %%
"Hello, " * "World!"
# Out:
# "Hello, World!"

# %%
"Testing "^3
# Out:
# "Testing Testing Testing "

# %%
string(5), string(5, base=16, pad=4)
# Out:
# ("5", "0005")

# %%
string(12345), string(12345, base=16, pad=5)
# Out:
# ("12345", "03039")

# %%
string("a", "bc", "def", 1, true)
# Out:
# "abcdef1true"

# %%
repeat("ha", 3)
# Out:
# "hahaha"

# %%
repr(1), repr(zeros(3)), repr(1/3)
# Out:
# ("1", "[0.0, 0.0, 0.0]", "0.3333333333333333")

# %%
repr(big(1/3))
# Out:
# "0.333333333333333314829616256247390992939472198486328125"

# %%
SubString("abc", 1, 2)
# Out:
# "ab"

# %%
SubString("abc", 1:2)
# Out:
# "ab"

# %%
SubString("abc", 2) # = 2:end
# Out:
# "bc"

# %%
ascii("abcd0123")
# Out:
# "abcd0123"

# %%
ascii("π")
# Out:
# ArgumentError: invalid ASCII at index 1 in "π"
#
# Stacktrace:
#  [1] __throw_invalid_ascii(::String, ::Int64) at ./strings/util.jl:685
#  [2] ascii(::String) at ./strings/util.jl:681
#  [3] top-level scope at In[7]:1
#  [4] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
print(match(r"a+.*b+.*?d$"ism, "Goodbye,\nOh, angry\nBad world\n"))
# i: case insensitive; 
# s: . matches \n; 
# m: ^/$ match line ends, not whole str
# Out:
# RegexMatch("angry\nBad world")

# %%
SubstitutionString("Hello \\g<name>, it's \\1")
# Out:
# s"Hello \\g<name>, it's \\1"

# %%
subst = s"Hello \g<name>, it's\1"
# Out:
# s"Hello \\g<name>, it's\\1"

# %%
typeof(subst)
# Out:
# SubstitutionString{String}

# %%
msg = "#Hello# from Julia"
print(replace(
    msg, r"#(.+)# from (?<from>\w+)" => s"FROM: \g<from>\nMESSAGE: \1"))
# Out:
# FROM: Julia
# MESSAGE: Hello

# %%
println(raw"\ $x")
# Out:
# \ $x

# %%
println(raw"\"")
# Out:
# "

# %%
println(raw"\\\"")
# Out:
# \"

# %%
println(raw"\\x \\\"")
# Out:
# \\x \"

# %%
isvalid(Char(0xd799)), print(Char(0xd799))
# Out:
# 힙
# (true, nothing)

# %%
isvalid(Char(0xd800))
# Out:
# false

# %%
s = String(UInt8[0xfe, 0x80, 0x80, 0x80, 0x80, 0x80])
# Out:
# "\xfe\x80\x80\x80\x80\x80"

# %%
isvalid(SubString(s, 1, 2))
# Out:
# false

# %%
isvalid(Char, 0xd800), isvalid(Char(0xd799))
# Out:
# (false, true)

# %%
isvalid(String, SubString("this is valid", 1, 5))
# Out:
# true

# %%
str = "αβγdef"
isvalid(str, 1)
# Out:
# true

# %%
str[1]
# Out:
# 'α': Unicode U+03B1 (category Ll: Letter, lowercase)

# %%
isvalid(str, 2)
# Out:
# false

# %%
str[2]
# Out:
# StringIndexError("αβγdef", 2)
#
# Stacktrace:
#  [1] string_index_err(::String, ::Int64) at ./strings/string.jl:12
#  [2] getindex_continued(::String, ::Int64, ::UInt32) at ./strings/string.jl:220
#  [3] getindex(::String, ::Int64) at ./strings/string.jl:213
#  [4] top-level scope at In[13]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
rx = r"a(.)a"
m = match(rx, "cabac")
# Out:
# RegexMatch("aba", 1="b")

# %%
m.captures
# Out:
# 1-element Array{Union{Nothing, SubString{String}},1}:
#  "b"

# %%
m.match
# Out:
# "aba"

# %%
match(rx, "cabac", 3) === nothing
# Out:
# true

# %%
rx = r"a.a"
m = eachmatch(rx, "a1a2a3a")
# Out:
# Base.RegexMatchIterator(r"a.a", "a1a2a3a", false)

# %%
collect(m)
# Out:
# 2-element Array{RegexMatch,1}:
#  RegexMatch("a1a")
#  RegexMatch("a3a")

# %%
isless("a", "b"), "a" < "b"
# Out:
# (true, true)

# %%
"abc" == "abc", "abc" == "ABC"
# Out:
# (true, false)
