# %%
a = 1:3:20
# Out:
# 1:3:19

# %%
4 in a
# Out:
# true

# %%
5 in a
# Out:
# false

# %%
missing in a
# Out:
# missing

# %%
1 in [2, missing]
# Out:
# missing

# %%
2 in [2, missing]
# Out:
# true

# %%
missing in Set([1, 2])
# Out:
# false

# %%
unique([1, 2, 6, 2])
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  6

# %%
unique(x -> x^2, [-3, -2, -1, 1, 2, 3, 4])
# Out:
# 4-element Array{Int64,1}:
#  -3
#  -2
#  -1
#   4

# %%
b = [7, 6, 42, 6, 7, 42]
sort!(b)
# Out:
# 6-element Array{Int64,1}:
#   6
#   6
#   7
#   7
#  42
#  42

# %%
unique!(b)
# Out:
# 3-element Array{Int64,1}:
#   6
#   7
#  42

# %%
b
# Out:
# 3-element Array{Int64,1}:
#   6
#   7
#  42

# %%
extrema(b)
# Out:
# (6, 42)

# %%
extrema(sin, 0:π)
# Out:
# (0.0, 0.9092974268256817)

# %%
sin.(0:π)
# Out:
# 4-element Array{Float64,1}:
#  0.0
#  0.8414709848078965
#  0.9092974268256817
#  0.1411200080598672

# %%
argmax([0.1, -9, 8, π])
# Out:
# 3

# %%
argmax([3, 3, 1])
# Out:
# 1

# %%
argmax([3, 1, NaN])
# Out:
# 3

# %%
findmax([0.1, -9, 8, π])
# Out:
# (8.0, 3)

# %%
any([false, false, true])
# Out:
# true

# %%
all([false, true, true])
# Out:
# false

# %%
count(i -> (4 <= i <= 6), [0, 2, 4, 6, 8, 10])
# Out:
# 2

# %%
any(i -> (4 <= i <= 6), [0, 2, 4, 6, 8, 10])
# Out:
# true

# %%
all(i -> (4 <= i <= 6), [0, 2, 4, 6, 8, 10])
# Out:
# false

# %%
map(x -> 2x, [2, 4, 6])
# Out:
# 3-element Array{Int64,1}:
#   4
#   8
#  12

# %%
map(+, [1, 2, 3], [10, 20, 30])
# Out:
# 3-element Array{Int64,1}:
#  11
#  22
#  33

# %%
mapreduce(x -> x^2, +, [1:3;]) # 1 + 4 + 9
# Out:
# 14

# %%
first(b)
# Out:
# 6

# %%
first("string", 0)
# Out:
# ""

# %%
first("string")
# Out:
# 's': ASCII/Unicode U+0073 (category Ll: Letter, lowercase)

# %%
first("string", 3)
# Out:
# "str"

# %%
Base.front((1, 2, 3))
# Out:
# (1, 2)

# %%
Base.tail((1, 2, 3))
# Out:
# (2, 3)

# %%
step(1:10)
# Out:
# 1

# %%
step(1:2:10)
# Out:
# 2

# %%
step(range(2.5, stop=10.9, length=88))
# Out:
# 0.09655172413793103

# %%
collect(1:2:11)
# Out:
# 6-element Array{Int64,1}:
#   1
#   3
#   5
#   7
#   9
#  11

# %%
collect(Float64, 1:2:9)
# Out:
# 5-element Array{Float64,1}:
#  1.0
#  3.0
#  5.0
#  7.0
#  9.0

# %%
a = 1:10
filter(isodd, a)
# Out:
# 5-element Array{Int64,1}:
#  1
#  3
#  5
#  7
#  9

# %%
d = Dict(1 => "a", 2 => "b")
filter(p -> isodd(p.first), d)
# Out:
# Dict{Int64,String} with 1 entry:
#   1 => "a"

# %%
x = [1 2; missing 4]
filter(isodd, skipmissing(x))
# Out:
# 1-element Array{Int64,1}:
#  1

# %%
replace([1, 2, 1, 3], 1 => 0, 2 => 4, count=2)
# Out:
# 4-element Array{Int64,1}:
#  0
#  4
#  1
#  3

# %%
replace([1, missing], missing => 0)
# Out:
# 2-element Array{Int64,1}:
#  1
#  0

# %%
replace(x -> isodd(x) ? 2x : x, [1, 2, 3, 4])
# Out:
# 4-element Array{Int64,1}:
#  2
#  2
#  6
#  4

# %%
A = Dict("a" => 1, "b" => 2)
getindex(A, "a")
# Out:
# 1

# %%
setindex!(A, 3, "a")
A
# Out:
# Dict{String,Int64} with 2 entries:
#   "b" => 2
#   "a" => 3

# %%
setindex!(A, 4, "c")
# Out:
# Dict{String,Int64} with 3 entries:
#   "c" => 4
#   "b" => 2
#   "a" => 3

# %%
firstindex([1, 2, 4])
# Out:
# 1

# %%
r = rand(3, 4, 5)
# Out:
# 3×4×5 Array{Float64,3}:
# [:, :, 1] =
#  0.783417  0.953213  0.46851   0.635539
#  0.038292  0.136317  0.919639  0.918538
#  0.182156  0.713929  0.619509  0.979313
#
# [:, :, 2] =
#  0.17794   0.0608026  0.364749   0.904145
#  0.6105    0.534499   0.0527339  0.883881
#  0.746638  0.486657   0.953897   0.988404
#
# [:, :, 3] =
#  0.0193425  0.523969  0.0518554  0.585825
#  0.406405   0.883356  0.377603   0.821743
#  0.737634   0.759548  0.856389   0.941135
#
# [:, :, 4] =
#  0.574261  0.171435  0.0157879  0.174314
#  0.840588  0.444241  0.17042    0.728953
#  0.418993  0.346647  0.246556   0.958763
#
# [:, :, 5] =
#  0.764793  0.400497  0.251285  0.307586
#  0.202186  0.501716  0.410717  0.907939
#  0.400763  0.515611  0.979022  0.783695

# %%
firstindex(r, 2)
# Out:
# 1

# %%
lastindex([1, 2, 4])
# Out:
# 3

# %%
lastindex(r, 2)
# Out:
# 4

# %% [markdown]
# ## Dictionaries

# %%
Dict([('A', 1), ('B', 2)])
# Out:
# Dict{Char,Int64} with 2 entries:
#   'A' => 1
#   'B' => 2

# %%
D = Dict('A' => 1, 'B' => 2)
# Out:
# Dict{Char,Int64} with 2 entries:
#   'A' => 1
#   'B' => 2

# %%
haskey(D, 'A')
# Out:
# true

# %%
haskey(D, "A")
# Out:
# false

# %%
get(D, 'A', 3)
# Out:
# 1

# %%
get(D, 'C', 7)
# Out:
# 7

# %%
get!(D, 'C', 7)
# Out:
# 7

# %%
D
# Out:
# Dict{Char,Int64} with 3 entries:
#   'C' => 7
#   'A' => 1
#   'B' => 2

# %%
getkey(D, 'A', 'a')
# Out:
# 'A': ASCII/Unicode U+0041 (category Lu: Letter, uppercase)

# %%
getkey(D, 'D', 'd')
# Out:
# 'd': ASCII/Unicode U+0064 (category Ll: Letter, lowercase)

# %%
delete!(D, 'B')
# Out:
# Dict{Char,Int64} with 2 entries:
#   'C' => 7
#   'A' => 1

# %%
pop!(D, 'C')
# Out:
# 7

# %%
D
# Out:
# Dict{Char,Int64} with 1 entry:
#   'A' => 1

# %%
D['E'] = 5
# Out:
# 5

# %%
for k in keys(D)
    print(k, " ")
end
# Out:
# A E

# %%
for v in values(D)
    print(v, " ")
end
# Out:
# 1 5

# %%
collect(values(D))
# Out:
# 2-element Array{Int64,1}:
#  1
#  5

# %%
A = ['a' 'd'; 'b' 'e'; 'c' 'f']
for (i, val) in pairs(IndexStyle(A), A)
    println("$i: $val")
end
# Out:
# 1: a
# 2: b
# 3: c
# 4: d
# 5: e
# 6: f

# %%
S = view(A, 1:2, :)
for (i, val) in pairs(IndexStyle(S), S)
    println("$i: $val")
end
# Out:
# CartesianIndex(1, 1): a
# CartesianIndex(2, 1): b
# CartesianIndex(1, 2): d
# CartesianIndex(2, 2): e

# %%
a = Dict("foo" => 0., "bar" => 42.)
b = Dict("baz" => 17, "bar" => 4711)
merge(a, b)
# Out:
# Dict{String,Float64} with 3 entries:
#   "bar" => 4711.0
#   "baz" => 17.0
#   "foo" => 0.0

# %%
merge(b, a)
# Out:
# Dict{String,Float64} with 3 entries:
#   "bar" => 42.0
#   "baz" => 17.0
#   "foo" => 0.0

# %%
merge(+, a, b)
# Out:
# Dict{String,Float64} with 3 entries:
#   "bar" => 4753.0
#   "baz" => 17.0
#   "foo" => 0.0

# %%
merge((a=1, b=2), (b=3, c=(d=1)), (c=(d=2),))
# Out:
# (a = 1, b = 3, c = 2)

# %%
merge((a=1, b=2, c=3), (b=4, d=5))
# Out:
# (a = 1, b = 4, c = 3, d = 5)

# %%
merge((a=1, b=2, c=3), [:b => 4, :d => 5])
# Out:
# (a = 1, b = 4, c = 3, d = 5)

# %%
d1 = Dict(1 => 11, 3 => 333)
d2 = Dict(1 => 1, 4 => 4444)
merge!(d1, d2)
d1
# Out:
# Dict{Int64,Int64} with 3 entries:
#   4 => 4444
#   3 => 333
#   1 => 1

# %%
d2
# Out:
# Dict{Int64,Int64} with 2 entries:
#   4 => 4444
#   1 => 1

# %%
d1 = Dict(1 => 11, 3 => 333)
d2 = Dict(1 => 1, 4 => 4444)
merge!(+, d1, d2)
d1
# Out:
# Dict{Int64,Int64} with 3 entries:
#   4 => 4444
#   3 => 333
#   1 => 12

# %%
d1 = Dict(1 => 11, 3 => 333)
d2 = Dict(1 => 1, 4 => 4444)
merge!(-, d1, d2)
d1
# Out:
# Dict{Int64,Int64} with 3 entries:
#   4 => 4444
#   3 => 333
#   1 => 10

# %%
keytype(['a', 'b', 'c']) == Int
# Out:
# true

# %%
keytype([1 2; 3 4])
# Out:
# CartesianIndex{2}

# %%
keytype(Dict(1 => "foo"))
# Out:
# Int64

# %%
valtype(['a', 'b', 'c'])
# Out:
# Char

# %%
valtype(Dict(1 => "foo"))
# Out:
# String

# %%
Set([1, 2, 3, 2, 1])
# Out:
# Set{Int64} with 3 elements:
#   2
#   3
#   1

# %%
union([1, 2], [2, 3])
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
intersect([1, 2], [2, 3])
# Out:
# 1-element Array{Int64,1}:
#  2

# %%
setdiff([1, 2, 3], [3, 4, 5])
# Out:
# 2-element Array{Int64,1}:
#  1
#  2

# %%
symdiff([1, 2, 3], [3, 4, 5], [4, 5, 6])
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  6

# %%
symdiff([1, 2, 1], [2, 1, 2])
# Out:
# 2-element Array{Int64,1}:
#  1
#  2

# %%
symdiff(Set([1, 2, 1]), Set([2, 1, 2]))
# Out:
# Set{Int64} with 0 elements

# %%
issubset([1, 2], [1, 2, 3])
# Out:
# true

# %%
issetequal([1, 2, 2], [1, 1, 2])
# Out:
# true

# %% [markdown]
# ### Dequeues

# %%
a = [1, 2, 3]
push!(a, 4, 5, 6)
# Out:
# 6-element Array{Int64,1}:
#  1
#  2
#  3
#  4
#  5
#  6

# %%
pop!(a)
# Out:
# 6

# %%
a
# Out:
# 5-element Array{Int64,1}:
#  1
#  2
#  3
#  4
#  5

# %%
pushfirst!([1, 2, 3], 5, 6)
# Out:
# 5-element Array{Int64,1}:
#  5
#  6
#  1
#  2
#  3

# %%
a = [1, 2, 3]
popfirst!(a)
# Out:
# 1

# %%
a
# Out:
# 2-element Array{Int64,1}:
#  2
#  3

# %%
insert!(a, 2, 0)
# Out:
# 3-element Array{Int64,1}:
#  2
#  0
#  3

# %%
deleteat!(a, 2)
# Out:
# 2-element Array{Int64,1}:
#  2
#  3

# %%
deleteat!([6, 5, 4, 3], [true, false, true, false])
# Out:
# 2-element Array{Int64,1}:
#  5
#  3

# %%
A = [6, 5, 4, 3, 2, 1]
splice!(A, 5)
# Out:
# 2

# %%
A
# Out:
# 5-element Array{Int64,1}:
#  6
#  5
#  4
#  3
#  1

# %%
splice!(A, 5, 999)
# Out:
# 1

# %%
A
# Out:
# 5-element Array{Int64,1}:
#    6
#    5
#    4
#    3
#  999

# %%
splice!(A, 2, [0, 0, 0])
# Out:
# 5

# %%
A
# Out:
# 7-element Array{Int64,1}:
#    6
#    0
#    0
#    0
#    4
#    3
#  999

# %%
A = [-1, -2, -3, 5, 4, 3, -1]
splice!(A, 4:3, 2)
# Out:
# 0-element Array{Int64,1}

# %%
A
# Out:
# 8-element Array{Int64,1}:
#  -1
#  -2
#  -3
#   2
#   5
#   4
#   3
#  -1

# %%
resize!([6, 5, 4, 3, 2, 1], 3)
# Out:
# 3-element Array{Int64,1}:
#  6
#  5
#  4

# %%
a = resize!([6, 5, 4, 3, 2, 1], 8)
length(a)
# Out:
# 8

# %%
a
# Out:
# 8-element Array{Int64,1}:
#            6
#            5
#            4
#            3
#            2
#            1
#            0
#  12884901888

# %%
a = [1]
append!(a, [2, 3])
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
append!(a, [4, 5, 6])
# Out:
# 6-element Array{Int64,1}:
#  1
#  2
#  3
#  4
#  5
#  6

# %%
prepend!(a, 0)
# Out:
# 7-element Array{Int64,1}:
#  0
#  1
#  2
#  3
#  4
#  5
#  6

# %%
b = 'b'
Pair(b, a)
# Out:
# 'b' => [0, 1, 2, 3, 4, 5, 6]

# %%
p = "foo" => 7
typeof(p)
# Out:
# Pair{String,Int64}

# %%
p.first
# Out:
# "foo"

# %%
for x in p
    println(x)
end
# Out:
# foo
# 7
