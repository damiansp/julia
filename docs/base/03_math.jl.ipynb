# %%
3 \ 6
# Out:
# 2.0

# %%
a = rand()
b = rand()
a / b == b \ a
# Out:
# true

# %%
fma(2, 3, 5)
# Out:
# 11

# %%
muladd(2, 3, 5)
# Out:
# 11

# %%
args = (2, 3, 5)
fma(args...) == muladd(args...) == 2*3 + 5
# Out:
# true

# %%
inv(7)
# Out:
# 0.14285714285714285

# %%
inv(inv(7))
# Out:
# 7.0

# %%
inv(1+2im)
# Out:
# 0.2 - 0.4im

# %%
(1+2im) * inv(1+2im)
# Out:
# 1.0 + 0.0im

# %%
inv(2//3)
# Out:
# 3//2

# %%
div(9, 4) # Python 9//4 (int division)
# Out:
# 2

# %%
fld(5, 2) # floor(5/2)
# Out:
# 2

# %%
cld(5, 2) # ceil(5/2)
# Out:
# 3

# %%
mod(11, 3)
# Out:
# 2

# %%
11 % 3
# Out:
# 2

# %%
rem(11, 3)
# Out:
# 2
