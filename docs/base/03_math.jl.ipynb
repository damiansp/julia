# %%
3 \ 6
# Out:
# 2.0

# %%
a = rand()
b = rand()
a / b == b \ a
# Out:
# true

# %%
fma(2, 3, 5)
# Out:
# 11

# %%
muladd(2, 3, 5)
# Out:
# 11

# %%
args = (2, 3, 5)
fma(args...) == muladd(args...) == 2*3 + 5
# Out:
# true

# %%
inv(7)
# Out:
# 0.14285714285714285

# %%
inv(inv(7))
# Out:
# 7.0

# %%
inv(1+2im)
# Out:
# 0.2 - 0.4im

# %%
(1+2im) * inv(1+2im)
# Out:
# 1.0 + 0.0im

# %%
inv(2//3)
# Out:
# 3//2

# %%
div(9, 4) # Python 9//4 (int division)
# Out:
# 2

# %%
fld(5, 2) # floor(5/2)
# Out:
# 2

# %%
cld(5, 2) # ceil(5/2)
# Out:
# 3

# %%
mod(11, 3)
# Out:
# 2

# %%
11 % 3
# Out:
# 2

# %%
rem(11, 3)
# Out:
# 2

# %%
rem2pi(8.83, RoundNearest) # or RoundDown
# Out:
# 2.5468146928204134

# %%
rem(8.83, 2π)
# Out:
# 2.546814692820414

# %%
mod2pi(8.83)
# Out:
# 2.5468146928204134

# %%
divrem(7, 3)
# Out:
# (2, 1)

# %%
floor(7 / 3), 7 % 3
# Out:
# (2.0, 1)

# %%
3 // 5
# Out:
# 3//5

# %%
rationalize(5.6)
# Out:
# 28//5

# %%
rationalize(10.3)
# Out:
# 103//10

# %%
a = rationalize(BigInt, 10.3)
typeof(a), typeof(numerator(a))
# Out:
# (Rational{BigInt}, BigInt)

# %%
denominator(a)
# Out:
# 10

# %%
Int8(3) << 2 # 11 -> 1100
# Out:
# 12

# %%
bitstring(Int8(3))
# Out:
# "00000011"

# %%
bitstring(Int8(12))
# Out:
# "00001100"

# %%
B = BitVector([true, false, true, false, false])
# Out:
# 5-element BitArray{1}:
#  1
#  0
#  1
#  0
#  0

# %%
B << 1
# Out:
# 5-element BitArray{1}:
#  0
#  1
#  0
#  0
#  0

# %%
B << -1
# Out:
# 5-element BitArray{1}:
#  0
#  1
#  0
#  1
#  0

# %%
Int8(13) >> 2
# Out:
# 3

# %%
bitstring(Int8(13))
# Out:
# "00001101"

# %%
bitstring(Int8(3))
# Out:
# "00000011"

# %%
Int8(-14) >>> 2
# Out:
# 60

# %%
bitstring(Int8(-14))
# Out:
# "11110010"

# %%
bitstring(Int8(60))
# Out:
# "00111100"

# %%
2:5
# Out:
# 2:5

# %%
collect(2:5)
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
I = CartesianIndex(2, 1)
J = CartesianIndex(3, 3)
I:J
# Out:
# 2×3 CartesianIndices{2,Tuple{UnitRange{Int64},UnitRange{Int64}}}:
#  CartesianIndex(2, 1)  CartesianIndex(2, 2)  CartesianIndex(2, 3)
#  CartesianIndex(3, 1)  CartesianIndex(3, 2)  CartesianIndex(3, 3)

# %%
range(1, length=100)
# Out:
# 1:100

# %%
range(3, stop=27)
# Out:
# 3:27

# %%
range(2, step=5, length=30)
# Out:
# 2:5:147

# %%
range(1, 10, length=101)
# Out:
# 1.0:0.09:10.0

# %%
range(1, 100, step=5)
# Out:
# 1:5:96

# %%
cmp(1, 2) # 1 < 2 -> -1
# Out:
# -1

# %%
cmp(2, 1) # 2 > 1 -> 1
# Out:
# 1

# %%
cmp(1, 1)
# Out:
# 0

# %%
cmp("abc", "ab c")
# Out:
# 1

# %%
~(0)
# Out:
# -1

# %%
~(1)
# Out:
# -2

# %%
~true
# Out:
# false

# %%
isapprox(10, 11; atol=2)
# Out:
# true

# %%
isapprox([10.0^9, 1.], [10.0^9, 2.])
# Out:
# true

# %%
sincos(π/4) # returns (sin, cos)
# Out:
# (0.7071067811865475, 0.7071067811865476)

# %%
sind(45) # sin (degrees)
# Out:
# 0.7071067811865476
