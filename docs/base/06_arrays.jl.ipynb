# %%
A = Array{Float64, 2}(undef, 2, 3)
# Out:
# 2×3 Array{Float64,2}:
#  2.18237e-314  2.18237e-314  2.18237e-314
#  2.18237e-314  2.18237e-314  2.29888e-314

# %%
B = Array{Float64}(undef, 2)
# Out:
# 2-element Array{Float64,1}:
#  2.2378116083e-314
#  2.444128497e-314

# %%
Array{Union{Nothing, Int}}(nothing, 2, 3)
# Out:
# 2×3 Array{Union{Nothing, Int64},2}:
#  nothing  nothing  nothing
#  nothing  nothing  nothing

# %%
Array{Union{Nothing, String}}(nothing, 2)
# Out:
# 2-element Array{Union{Nothing, String},1}:
#  nothing
#  nothing

# %%
Array{Union{Missing, String}}(missing, 2)
# Out:
# 2-element Array{Union{Missing, String},1}:
#  missing
#  missing

# %%
Array{Union{Missing, Int}}(missing, 2, 3)
# Out:
# 2×3 Array{Union{Missing, Int64},2}:
#  missing  missing  missing
#  missing  missing  missing

# %%
Array{Float64, 1}(UndefInitializer(), 3)
# Out:
# 3-element Array{Float64,1}:
#  2.2366077166e-314
#  2.2803473245e-314
#  2.182382834e-314

# %%
Array{Float64, 1}(undef, 3)
# Out:
# 3-element Array{Float64,1}:
#  2.2965547883e-314
#  2.296554804e-314
#  2.29655482e-314

# %%
Vector{Float64}(undef, 3) # a necesssarily 1D Array
# Out:
# 3-element Array{Float64,1}:
#  2.2965591835e-314
#  2.2042036267e-314
#  2.203118026e-314

# %%
Vector{Union{Nothing, String}}(nothing, 2)
# Out:
# 2-element Array{Union{Nothing, String},1}:
#  nothing
#  nothing

# %%
Vector{Union{Missing, String}}(missing, 2)
# Out:
# 2-element Array{Union{Missing, String},1}:
#  missing
#  missing

# %%
Matrix{Union{Nothing, String}}(nothing, 2, 3)
# Out:
# 2×3 Array{Union{Nothing, String},2}:
#  nothing  nothing  nothing
#  nothing  nothing  nothing

# %%
Matrix{Union{Missing, String}}(missing, 3, 2)
# Out:
# 3×2 Array{Union{Missing, String},2}:
#  missing  missing
#  missing  missing
#  missing  missing

# %%
a = Int8[0, 1, 2, 3]
getindex(a, 2), getindex(a, 4)
# Out:
# (1, 3)

# %%
a[2], a[4]
# Out:
# (1, 3)

# %%
zeros(1)
# Out:
# 1-element Array{Float64,1}:
#  0.0

# %%
zeros(Int8, 2, 3)
# Out:
# 2×3 Array{Int8,2}:
#  0  0  0
#  0  0  0

# %%
ones(1, 2)
# Out:
# 1×2 Array{Float64,2}:
#  1.0  1.0

# %%
ones(ComplexF64, 2, 3)
# Out:
# 2×3 Array{Complex{Float64},2}:
#  1.0+0.0im  1.0+0.0im  1.0+0.0im
#  1.0+0.0im  1.0+0.0im  1.0+0.0im

# %%
ba = BitArray(undef, 2, 2) # boolean only
# Out:
# 2×2 BitArray{2}:
#  0  0
#  0  0

# %%
ba[1, 1] = 1
# Out:
# 1

# %%
ba
# Out:
# 2×2 BitArray{2}:
#  1  0
#  0  0

# %%
ba[2, 2] = 3
# Out:
# InexactError: Bool(3)
#
# Stacktrace:
#  [1] Bool at ./float.jl:73 [inlined]
#  [2] convert at ./number.jl:7 [inlined]
#  [3] setindex! at ./bitarray.jl:688 [inlined]
#  [4] _setindex! at ./abstractarray.jl:1176 [inlined]
#  [5] setindex!(::BitArray{2}, ::Int64, ::Int64, ::Int64) at ./abstractarray.jl:1153
#  [6] top-level scope at In[9]:1
#  [7] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
BitArray(x + y == 3 for x = 1:2, y = 1:3)
# Out:
# 2×3 BitArray{2}:
#  0  1  0
#  1  0  0

# %%
trues(2, 3)
# Out:
# 2×3 BitArray{2}:
#  1  1  1
#  1  1  1

# %%
typeof(trues(2, 3))
# Out:
# BitArray{2}

# %%
fill(5, (2, 3))
# Out:
# 2×3 Array{Int64,2}:
#  5  5  5
#  5  5  5
