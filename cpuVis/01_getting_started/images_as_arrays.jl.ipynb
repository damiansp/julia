# %%
using Images

# %%
img = load("../images/cat_download.jpg")
img
# Out:
# 360×640 Array{RGB4{N0f8},2} with eltype RGB4{Normed{UInt8,8}}:
#  RGB4{N0f8}(0.353,0.286,0.216)  …  RGB4{N0f8}(0.369,0.325,0.251)
#  RGB4{N0f8}(0.353,0.286,0.216)     RGB4{N0f8}(0.388,0.345,0.271)
#  RGB4{N0f8}(0.345,0.278,0.208)     RGB4{N0f8}(0.396,0.353,0.278)
#  RGB4{N0f8}(0.329,0.263,0.192)     RGB4{N0f8}(0.396,0.353,0.278)
#  RGB4{N0f8}(0.306,0.243,0.176)     RGB4{N0f8}(0.4,0.357,0.282)
#  RGB4{N0f8}(0.282,0.22,0.153)   …  RGB4{N0f8}(0.404,0.361,0.286)
#  RGB4{N0f8}(0.251,0.2,0.137)       RGB4{N0f8}(0.404,0.361,0.282)
#  RGB4{N0f8}(0.231,0.18,0.118)      RGB4{N0f8}(0.408,0.365,0.286)
#  RGB4{N0f8}(0.227,0.176,0.114)     RGB4{N0f8}(0.408,0.365,0.286)
#  RGB4{N0f8}(0.22,0.169,0.106)      RGB4{N0f8}(0.412,0.369,0.29)
#  RGB4{N0f8}(0.212,0.157,0.106)  …  RGB4{N0f8}(0.416,0.373,0.294)
#  RGB4{N0f8}(0.212,0.157,0.106)     RGB4{N0f8}(0.416,0.373,0.294)
#  RGB4{N0f8}(0.22,0.157,0.106)      RGB4{N0f8}(0.42,0.376,0.298)
#  ⋮                              ⋱
# ...

# %%
img[1:1, 1:1, :]
# Out:
# 1×1×1 Array{RGB4{N0f8},3} with eltype RGB4{Normed{UInt8,8}}:
# [:, :, 1] =
#  RGB4{N0f8}(0.353,0.286,0.216)
