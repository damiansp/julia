# %%
uppercase("Hello, World!")
# Out:
# "HELLO, WORLD!"

# %%
findfirst('a', "banana")
# Out:
# 2

# %%
findfirst("na", "banana")
# Out:
# 3:4

# %%
findnext("na", "banana", 4)
# Out:
# 5:6

# %%
'a' in "banana", 'a' ∈ "banana"
# Out:
# (true, true)
