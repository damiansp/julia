# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
println("Hello, World!")
# Out:
# Hello, World!

# %%
parse(Int64, "32")
# Out:
# 32

# %%
parse(Float64, "3.14159")
# Out:
# 3.14159

# %%
trunc(Int64, 3.9999)
# Out:
# 3

# %%
trunc(Int64, -2.3)
# Out:
# -2

# %%
float(32)
# Out:
# 32.0

# %%
string(43), string(3.14159)
# Out:
# ("43", "3.14159")

# %%
signal_power = 8
noise_power = 2.6
ratio = signal_power / noise_power
ratio
# Out:
# 3.0769230769230766

# %%
decibels = 10log10(ratio)
decibels
# Out:
# 4.881166390211256

# %%
radians = 0.7
height = sin(radians)
height
# Out:
# 0.644217687237691

# %%
degrees = 45
radians = π * degrees / 180
radians
# Out:
# 0.7853981633974483

# %%
sin(radians)
# Out:
# 0.7071067811865475

# %%
sqrt(2) / 2
# Out:
# 0.7071067811865476

# %%
x = sin(degrees / 2 * 360 * π)
x = exp(log(x + 1))
x
# Out:
# 0.9999999999977148

# %%
function sing()
    println("I'm a lumberjack and I'm OK")
    println("I sleep all night and I work all day")
end
# Out:
# sing (generic function with 1 method)

# %%
sing()
# Out:
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day

# %%
function repeatsing(n)
    for _ in 1:n
        sing()
    end
end
# Out:
# repeatsing (generic function with 2 methods)

# %%
repeatsing(3)
# Out:
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day

# %%
sing()
sing()
# Out:
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day
# I'm a lumberjack and I'm OK
# I sleep all night and I work all day
