# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789

# %%
minutes = 105
hours = minutes ÷ 60  # int division
minutes = minutes - 60hours
hours, minutes
# Out:
# (1, 45)

# %%
x = rand()
y = rand()
if x < y
    println("$x < $y")
elseif y < x
    println("$x > $y")
else
    println("$x = $y")
end
# Out:
# 0.974228324279271 > 0.5515433470825781
