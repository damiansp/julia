# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
x = 1:10
y = rand(10)
plot(x, y)

# %%
y = rand(10, 2)
plot(x, y)

# %%
z = rand(10)
plot!(x, z)

# %%
p = plot(x, y)
plot!(p, x, z)
