# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789

# %%
Inf
# Out:
# Inf

# %%
[1; 2; 3; 4]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
[1;; 2;; 3;; 4]
# Out:
# 1×4 Matrix{Int64}:
#  1  2  3  4

# %%
[[1, 2], [3, 4]]
# Out:
# 2-element Vector{Vector{Int64}}:
#  [1, 2]
#  [3, 4]

# %%
[1 2; 3 4]
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  3  4

# %%
[1 2
 3 4]
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  3  4

# %%
typeof(Inf)
# Out:
# Float64

# %%
reshape([1, 2, 3, 4], (2, 2))
# Out:
# 2×2 Matrix{Int64}:
#  1  3
#  2  4

# %%
a = [1, 2, 3, 4]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
a + a
# Out:
# 4-element Vector{Int64}:
#  2
#  4
#  6
#  8

# %%
a * reshape(a, (1, length(a)))
# Out:
# 4×4 Matrix{Int64}:
#  1  2   3   4
#  2  4   6   8
#  3  6   9  12
#  4  8  12  16

# %%
a / a
# Out:
# 4×4 Matrix{Float64}:
#  0.0333333  0.0666667  0.1  0.133333
#  0.0666667  0.133333   0.2  0.266667
#  0.1        0.2        0.3  0.4
#  0.133333   0.266667   0.4  0.533333

# %%
Float32.([4.3, 5, 0])
# Out:
# 3-element Vector{Float32}:
#  4.3
#  5.0
#  0.0

# %%
f(x) = 7x^2 / (4 + 5x^3)
# Out:
# f (generic function with 1 method)

# %%
x = [2π / n for n = 1:3]
# Out:
# 3-element Vector{Float64}:
#  6.283185307179586
#  3.141592653589793
#  2.0943951023931953

# %%
y = f.(x)
# Out:
# 3-element Vector{Float64}:
#  0.22210061177582122
#  0.43442513879920297
#  0.6149053316945388

# %%
x = [2, 4, 5]
y = 3x.^3 + 6x.^5
# Out:
# 3-element Vector{Int64}:
#    216
#   6336
#  19125

# %%
y = sin.(x)
# Out:
# 3-element Vector{Float64}:
#   0.9092974268256817
#  -0.7568024953079282
#  -0.9589242746631385

# %%
ex = rand(5, 7)
# Out:
# 5×7 Matrix{Float64}:
#  0.973294   0.522628   0.0375018  0.437954  0.905691   0.637518  0.256942
#  0.492483   0.547353   0.462311   0.473748  0.632264   0.453112  0.983886
#  0.0930462  0.594877   0.190212   0.080669  0.121929   0.942751  0.278297
#  0.181067   0.964983   0.931175   0.60804   0.0457078  0.740246  0.291115
#  0.631865   0.0730197  0.21214    0.170849  0.0381376  0.590371  0.458647

# %%
ex1 = rand(Int64, 5, 7)
# Out:
# 5×7 Matrix{Int64}:
#   6962682040689853067   4617095061113035874  …   -837766811697024421
#   3839419691737321639   7865905657490820686      2047769045435606947
#  -6054372065486504542  -6942978352259953269     -1862098770733719657
#   4182425912045089873  -4382858997032914653     -6299346599434724316
#   8067387441547453471   5718287063293020960     -5927954979854863144

# %%
length(ex)
# Out:
# 35

# %%
a = 4
b = a
n = copy(a)
a = 6
(a, b, n)
# Out:
# (6, 4, 4)

# %%
r = [3.4, 5]
s = r
r[1] = 3
t = copy(r)
r[2] = 7
(r, s, t)
# Out:
# ([3.0, 7.0], [3.0, 7.0], [3.0, 5.0])

# %%
g = 7
typeof(g)
# Out:
# Int64

# %%
h = 45.6
typeof(h)
# Out:
# Float64

# %%
try
    log(-54)
catch e
    println("Can't be negative")
    println(e)
end
# Out:
# Can't be negative
# DomainError(-54.0, "log was called with a negative real argument but will only return a complex result if called with a complex argument. Try log(Complex(x)).")

# %%
p = try
    log(-54)
catch e
    throw(e)
finally
    println("Always log me")
end
# Out:
# Always log me
# DomainError with -54.0:
# log was called with a negative real argument but will only return a complex result if called with a complex argument. Try log(Complex(x)).
#
# Stacktrace:
#  [1] top-level scope
#    @ In[29]:4
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
for x in range(1, 1, 3)
    println("Yo")
end
# Out:
# Yo
# Yo
# Yo
