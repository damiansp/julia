# %%
mutable struct CallTest
    a::Float64
end

# %%
(c::CallTest)(b::Float64) = c.a * b

# %%
c = CallTest(2.)
c(3.)
# Out:
# 6.0

# %%
(c::CallTest)(b::Int) = c.a / b

# %%
c(3)
# Out:
# 0.6666666666666666
