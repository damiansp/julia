# %%
using Plots

# %%
plot(rand(100))

# %%
a = 5
b = 2a^2 + 30a + 9
# Out:
# 209

# %%
x = range(0, stop=5, length=101)
y = cos.(2x .+ 5)
plot(x, y)

# %%
using PyPlot

# %%
x = range(0, stop=5, length=101)
y = cos.(2x .+ 5)
plot(x, y)
title("cosine graph")
xlabel("x")
ylabel("cos(2x + 5)")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'cos(2x + 5)')
