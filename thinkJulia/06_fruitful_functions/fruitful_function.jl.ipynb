# %%
function distance(x1, y1, x2, y2)
    dx = x2 - x1
    dy = y2 - y1
    dsq = dx^2 + dy^2
    @show dsq
    sqrt(dsq)
end
# Out:
# distance (generic function with 1 method)

# %%
distance(0, 0, 3, 4)
# Out:
# dsq = 25
# 5.0

# %%
function fact(n)
    if n == 0
        return 1
    else
        recurse = fact(n - 1)
        result = n * recurse
        return result
    end
end
# Out:
# fact (generic function with 1 method)

# %%
fact(7)
# Out:
# 5040

# %%
function fact(n)
    if n == 0
        return 1
    else
        return n * fact(n - 1)
    end
end
# Out:
# fact (generic function with 1 method)

# %%
fact(8)
# Out:
# 40320

# %%
function fib(n)
    if n == 0
        return 0
    elseif n == 1
        return 1
    else
        return fib(n - 1) + fib(n - 2)
    end
end
# Out:
# fib (generic function with 1 method)

# %%
fib(8)
# Out:
# 21

# %%
function fact(n)
    if !(n isa Int64)
        error("Factorial only defined for integers")
    elseif n < 0
        error("Factorial not defined for negative numbers")
    elseif n == 0
        return 1
    else
        return n * fact(n - 1)
    end
end
# Out:
# fact (generic function with 1 method)

# %%
fact(2.6)
# Out:
# Factorial only defined for integers
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] fact(::Float64) at ./In[1]:3
#  [3] top-level scope at In[2]:1

# %%
fact(-2)
# Out:
# Factorial not defined for negative numbers
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] fact(::Int64) at ./In[1]:5
#  [3] top-level scope at In[3]:1
