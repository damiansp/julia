# %%
struct Point
    x
    y
end

# %%
p = Point(3., 4.)
# Out:
# Point(3.0, 4.0)

# %%
x = p.x
y = p.y
x, y
# Out:
# (3.0, 4.0)

# %%
distance_from_origin = sqrt(p.x^2 + p.y^2)
distance_from_origin
# Out:
# 5.0

# %%
p.y = 1.
# Out:
# setfield! immutable struct of type Point cannot be changed
#
# Stacktrace:
#  [1] setproperty!(::Point, ::Symbol, ::Float64) at ./sysimg.jl:19
#  [2] top-level scope at In[5]:1
