# %%
minutes = 105
hours = minutes / 60
hours
# Out:
# 1.75

# %%
full_hours = minutes ÷ 60
full_hours
# Out:
# 1

# %%
remainder = minutes - full_hours*60
remainder
# Out:
# 45

# %%
remainder = minutes % 60
remainder
# Out:
# 45
