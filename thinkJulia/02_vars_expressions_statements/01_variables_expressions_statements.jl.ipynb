# %% [markdown]
# # Assignment

# %%
msg = "my message"
n = 17
π = 3.14159265358979
# Out:
# 3.14159265358979

# %%
marathonmiles = 26.2
marathonkm = marathonmiles * 1.61
# Out:
# 42.182

# %%
s1 = "Ju"
s2 = "lia"
s1 * s2
# Out:
# "Julia"

# %%
(s1 * s2)^3
# Out:
# "JuliaJuliaJulia"

# %%
x = y = 1
x, y
# Out:
# (1, 1)

# %%
x = 1;
x
# Out:
# 1

# %%
a = 3
b = 5
x = 5a - 2b
x
# Out:
# 5

# %%
r = 5
spherevol = (4/3) * π * r^3
spherevol
# Out:
# 523.5987755982983

# %%
coverprice = 24.95
discount = 0.6
shippingfirst = 3
shippingadditional = 0.75

n = 60
priceforn = ((n * coverprice * discount) 
             + shippingfirst 
             + (n - 1)*shippingadditional)
priceforn
# Out:
# 945.4499999999999

# %%
leave = (6, 52, 0)
timepermile = (0, 8, 15)
timepersprint = (0, 7, 12)
sprinttime = 3 .* timepersprint
leave .+ timepermile .+ sprinttime #  7:21:51
# Out:
# (6, 81, 51)
