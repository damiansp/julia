# %%
# New in 0.6
Array{Int64, 3}
# Out:
# Array{Int64,3}

# %%
greeting = "Hello, world!"
# Out:
# "Hello, world!"

# %%
println(greeting)
# Out:
# Hello, world!

# %%
人 = 20
生 = 11.111
[人, 生]
# Out:
# 2-element Array{Float64,1}:
#  20.0
#  11.111

# %%
_this_is_my_idea_of_a_long_variable_name_ = "short string"
# Out:
# "short string"

# %%
very_important!pay_attention = "wake-up call"
# Out:
# "wake-up call"

# %%
# New in 0.6
abs_type_var = Array{Int64, 2}
# Out:
# Array{Int64,2}

# %%
abs_type_var
# Out:
# Array{Int64,2}

# %%
#abs_type_var[2,1]

# %%
abs_type_var[1, 1] = 1    # Int64 is a subtype of Integer
# Out:
# MethodError: no method matching setindex!(::Type{Array{Int64,2}}, ::Int64, ::Int64, ::Int64)
#
# Stacktrace:
#  [1] top-level scope at In[27]:1

# %%
abstypevariable
# Out:
# 2×3 Array{Integer,2}:
#    1     #undef  #undef
#  #undef  #undef  #undef

# %%
abstypevariable[1,2] = 5.0  # given value is of type Float64
# Out:
# 5.0

# %%
abstypevariable
# Out:
# 2×3 Array{Integer,2}:
#    1       5     #undef
#  #undef  #undef  #undef

# %%
abstypevariable[2,2] = "stringystringstr"  # strings cannot be converted to any Integer type
# Out:
# MethodError: Cannot `convert` an object of type String to an object of type Integer
# This may have arisen from a call to the constructor Integer(...),
# since type constructors fall back to convert methods.
#
# Stacktrace:
#  [1] setindex!(::Array{Integer,2}, ::String, ::Int64, ::Int64) at .\array.jl:550
#  [2] include_string(::String, ::String) at .\loading.jl:515

# %%
# New in 0.6
arbconcretevariable = Array{Int64}(2,3)  # no actual value specified, 
#                                             ... so Julia assigns arbitrary values
# Out:
# 2×3 Array{Int64,2}:
#  379046192  379046352  379058416
#  379046288  379046416  379056816
