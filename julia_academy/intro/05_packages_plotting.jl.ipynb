# %%
#=
import Pkg
Pkg.add("Colors")
Pkg.add("Example")
Pkg.add("Plots")
Pkg.add("PlotlyJS")
=#

# %%
using Colors
using Example
using Plots

# %%
hello("is it me you're looking for?")
# Out:
# "Hello, is it me you're looking for?"

# %%
palette = distinguishable_colors(20)
# Out:
# 20-element Vector{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.0, 0.0, 0.0)
#  RGB(1.0, 1.0, 0.455)
#  RGB(1.0, 0.608, 1.0)
#  RGB(0.0, 0.827, 1.0)
#  RGB(0.886, 0.388, 0.051)
#  RGB(0.0, 0.494, 0.0)
#  RGB(0.0, 0.314, 0.902)
#  RGB(0.675, 0.0, 0.278)
#  RGB(0.0, 1.0, 0.784)
#  RGB(0.0, 0.392, 0.408)
#  RGB(1.0, 0.835, 0.769)
#  RGB(0.424, 0.322, 0.0)
#  RGB(0.478, 0.459, 0.506)
#  RGB(0.267, 0.0, 0.361)
#  RGB(0.62, 0.62, 0.467)
#  RGB(1.0, 0.361, 0.471)
#  RGB(0.506, 0.592, 0.945)
#  RGB(0.0, 0.196, 0.0)
#  RGB(0.78, 0.129, 0.867)
#  RGB(1.0, 0.678, 0.027)

# %%
rand(palette, 3, 3)
# Out:
# 3×3 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.478, 0.459, 0.506)  RGB(1.0, 0.835, 0.769)    RGB(0.0, 0.494, 0.0)
#  RGB(1.0, 0.361, 0.471)    RGB(1.0, 0.608, 1.0)      RGB(0.478, 0.459, 0.506)
#  RGB(0.506, 0.592, 0.945)  RGB(0.886, 0.388, 0.051)  RGB(0.0, 0.392, 0.408)

# %%
x = -3:0.1:3
y = x.^2
# Out:
# 61-element Vector{Float64}:
#  9.0
#  8.41
#  7.839999999999999
#  7.290000000000001
#  6.760000000000001
#  6.25
#  5.76
#  5.289999999999999
#  4.840000000000001
#  4.41
#  4.0
#  3.61
#  3.24
#  ⋮
#  3.61
#  4.0
#  4.41
#  4.840000000000001
#  5.289999999999999
#  5.76
#  6.25
#  6.760000000000001
#  7.290000000000001
#  7.839999999999999
#  8.41
#  9.0

# %%
gr() # GR backend
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
plotlyjs()
# Out:
# [ Info: Precompiling PlotlyJS [f0f68f2c-4968-5e81-91da-67840de0976a] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-affe-3255-4b5c-5a24797dc5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing PlotlyJS [f0f68f2c-4968-5e81-91da-67840de0976a].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling PlotlyBase [a03496cd-edff-5a9b-9e67-9cda94a718b5] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-affe-3255-4b5c-5a24797dc5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing PlotlyBase [a03496cd-edff-5a9b-9e67-9cda94a718b5].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling IJuliaExt [ca55ebba-d40a-59bc-9445-d114519c28be] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module PlotlyBase with build ID ffffffff-ffff-ffff-8c93-05596df7b0bd is missing from the cache.
# │ This may mean PlotlyBase [a03496cd-edff-5a9b-9e67-9cda94a718b5] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing IJuliaExt [ca55ebba-d40a-59bc-9445-d114519c28be].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling PlotlyKaleido [f2990250-8cf9-495f-b13a-cce12b45703c] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-affe-3255-4b5c-5a24797dc5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing PlotlyKaleido [f2990250-8cf9-495f-b13a-cce12b45703c].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling WebIO [0f1e0344-ec1d-5b48-a673-e5cf874b6c29] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-affe-3255-4b5c-5a24797dc5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing WebIO [0f1e0344-ec1d-5b48-a673-e5cf874b6c29].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling AssetRegistry [bf4720bc-e11a-5d0c-854e-bdca1663c893] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-affe-3255-4b5c-5a24797dc5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing AssetRegistry [bf4720bc-e11a-5d0c-854e-bdca1663c893].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# LoadError: UndefVarError: `Writer` not defined in `JSON`
# Suggestion: check for spelling errors or missing imports.
# in expression starting at /Users/damiansp/.julia/packages/WebIO/8Xm9p/src/syntax.jl:229
# in expression starting at /Users/damiansp/.julia/packages/WebIO/8Xm9p/src/WebIO.jl:1
# in expression starting at /Users/damiansp/.julia/packages/PlotlyJS/60kan/src/PlotlyJS.jl:1
#
# Stacktrace:
#   [1] getproperty(x::Module, f::Symbol)
#     @ Base ./Base_compiler.jl:47
#   [2] top-level scope
#     @ ~/.julia/packages/WebIO/8Xm9p/src/syntax.jl:229
#   [3] include(mapexpr::Function, mod::Module, _path::String)
#     @ Base ./Base.jl:307
#   [4] top-level scope
#     @ ~/.julia/packages/WebIO/8Xm9p/src/WebIO.jl:40
#   [5] include(mod::Module, _path::String)
#     @ Base ./Base.jl:306
#   [6] __require_prelocked(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:2719
#   [7] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2493
#   [8] macro expansion
#     @ ./loading.jl:2421 [inlined]
#   [9] macro expansion
#     @ ./lock.jl:376 [inlined]
#  [10] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2386
#  [11] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2362
#  [12] top-level scope
#     @ ~/.julia/packages/PlotlyJS/60kan/src/PlotlyJS.jl:18
#  [13] include(mod::Module, _path::String)
#     @ Base ./Base.jl:306
#  [14] __require_prelocked(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:2719
#  [15] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2493
#  [16] macro expansion
#     @ ./loading.jl:2421 [inlined]
#  [17] macro expansion
#     @ ./lock.jl:376 [inlined]
#  [18] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2386
#  [19] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2362
#  [20] top-level scope
#     @ ~/.julia/packages/Plots/pxXHF/src/backends.jl:392
#  [21] eval(m::Module, e::Any)
#     @ Core ./boot.jl:489
#  [22] _initialize_backend(pkg::Plots.PlotlyJSBackend)
#     @ Plots ~/.julia/packages/Plots/pxXHF/src/backends.jl:391
#  [23] backend(pkg::Plots.PlotlyJSBackend)
#     @ Plots ~/.julia/packages/Plots/pxXHF/src/backends.jl:256
#  [24] plotlyjs()
#     @ Plots ~/.julia/packages/Plots/pxXHF/src/backends.jl:97
#  [25] top-level scope
#     @ In[15]:1
#  [26] eval(m::Module, e::Any)
#     @ Core ./boot.jl:489

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
globaltemp = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
npirates = [45000, 20000, 15000, 5000, 400, 12]
plot(npirates, globaltemp, legend=false)
scatter!(npirates, globaltemp, legend=false)
#xflip!()
xlabel!("No. Pirates")
ylabel!("Global Temp (C)")
title!("Pirating Prevents Global Warming")

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout=(2, 2), legend=false)
