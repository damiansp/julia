# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#234567890
#=
import Pkg
Pkg.add("Colors")
Pkg.add("Example")
Pkg.add("Plots")
Pkg.add("PlotlyJS")
=#

# %%
using Colors
using Example
using Plots

# %%
hello("is it me you're looking for?")
# Out:
# "Hello, is it me you're looking for?"

# %%
palette = distinguishable_colors(20)
# Out:
# 20-element Vector{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.0, 0.0, 0.0)
#  RGB(1.0, 1.0, 0.455)
#  RGB(1.0, 0.608, 1.0)
#  RGB(0.0, 0.827, 1.0)
#  RGB(0.886, 0.388, 0.051)
#  RGB(0.0, 0.494, 0.0)
#  RGB(0.0, 0.314, 0.902)
#  RGB(0.675, 0.0, 0.278)
#  RGB(0.0, 1.0, 0.784)
#  RGB(0.0, 0.392, 0.408)
#  RGB(1.0, 0.835, 0.769)
#  RGB(0.424, 0.322, 0.0)
#  RGB(0.478, 0.459, 0.506)
#  RGB(0.267, 0.0, 0.361)
#  RGB(0.62, 0.62, 0.467)
#  RGB(1.0, 0.361, 0.471)
#  RGB(0.506, 0.592, 0.945)
#  RGB(0.0, 0.196, 0.0)
#  RGB(0.78, 0.129, 0.867)
#  RGB(1.0, 0.678, 0.027)

# %%
rand(palette, 3, 3)
# Out:
# 3×3 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.0, 0.827, 1.0)  RGB(0.0, 1.0, 0.784)    RGB(0.506, 0.592, 0.945)
#  RGB(1.0, 0.608, 1.0)  RGB(0.424, 0.322, 0.0)  RGB(0.478, 0.459, 0.506)
#  RGB(1.0, 1.0, 0.455)  RGB(0.0, 0.392, 0.408)  RGB(0.675, 0.0, 0.278)

# %%
x = -3:0.1:3
y = x.^2
# Out:
# 61-element Vector{Float64}:
#  9.0
#  8.41
#  7.839999999999999
#  7.290000000000001
#  6.760000000000001
#  6.25
#  5.76
#  5.289999999999999
#  4.840000000000001
#  4.41
#  4.0
#  3.61
#  3.24
#  ⋮
#  3.61
#  4.0
#  4.41
#  4.840000000000001
#  5.289999999999999
#  5.76
#  6.25
#  6.760000000000001
#  7.290000000000001
#  7.839999999999999
#  8.41
#  9.0

# %%
gr() # GR backend
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
plotlyjs()
# Out:
# WebIO._IJuliaInit()
# Plots.PlotlyJSBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
globaltemp = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
npirates = [45000, 20000, 15000, 5000, 400, 12]
plot(npirates, globaltemp, legend=false)
scatter!(npirates, globaltemp, legend=false)
xflip!()
xlabel!("No. Pirates")
ylabel!("Global Temp (C)")
title!("Pirating Prevents Global Warming")

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout=(2, 2), legend=false)
