# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#234567890
1:5
# Out:
# 1:5

# %%
collect(1:5)
# Out:
# 5-element Vector{Int64}:
#  1
#  2
#  3
#  4
#  5

# %%
collect(1:3:11)
# Out:
# 4-element Vector{Int64}:
#   1
#   4
#   7
#  10

# %%
m = [
    5 6
    7 8]
# Out:
# 2×2 Matrix{Int64}:
#  5  6
#  7  8

# %%
function doubp1(x)
    2x + 1
end
# Out:
# doubp1 (generic function with 1 method)

# %%
function halfm1(x) 
    x/2. - 1
end
# Out:
# halfm1 (generic function with 1 method)

# %%
halfm1(doubp1(9))
# Out:
# 8.5

# %%
(halfm1 ∘ doubp1)(9)
# Out:
# 8.5

# %%
9 |> doubp1 |> halfm1
# Out:
# 8.5

# %%
f(x) = 2x
# Out:
# f (generic function with 1 method)

# %%
f.([1, 3, 5])
# Out:
# 3-element Vector{Int64}:
#   2
#   6
#  10
